# %%
# 知识库文件内容与生成顺序见：
# graphrag/index/run.py中workflow_dependencies变量
# https://www.bilibili.com/video/BV1u6iFeAEx9?p=8
"""
├── Loading Input (text)
├── create_base_text_units
├── create_base_extracted_entities
├── create_summarized_entities
├── create_base_entity_graph
├── create_final_entities
├── create_final_nodes
├── create_final_communities
├── join_text_units_to_entity_ids
├── create_final_relationships
├── join_text_units_to_relationship_ids
├── create_final_community_reports
├── create_final_text_units
├── create_base_documents
└── create_final_documents
"""
# Out:
# '\n├── Loading Input (text)\n├── create_base_text_units\n├── create_base_extracted_entities\n├── create_summarized_entities\n├── create_base_entity_graph\n├── create_final_entities\n├── create_final_nodes\n├── create_final_communities\n├── join_text_units_to_entity_ids\n├── create_final_relationships\n├── join_text_units_to_relationship_ids\n├── create_final_community_reports\n├── create_final_text_units\n├── create_base_documents\n└── create_final_documents\n'

# %%
import io

import pandas as pd
import networkx as nx
from pyvis.network import Network

path_prefix = "../kongyiji/output/kongyiji/artifacts/"

# %%
dependencies = {'create_base_text_units': [],
                'create_base_extracted_entities': ['create_base_text_units'],
                'create_summarized_entities': ['create_base_extracted_entities'],
                'create_base_entity_graph': ['create_summarized_entities'],
                'create_final_entities': ['create_base_entity_graph'],
                'create_final_nodes': ['create_base_entity_graph'],
                'create_final_communities': ['create_base_entity_graph'],
                'join_text_units_to_entity_ids': ['create_final_entities'],
                'create_final_relationships': ['create_final_nodes', 'create_base_entity_graph'],
                'join_text_units_to_relationship_ids': ['create_final_relationships'],
                'create_final_community_reports': ['create_final_relationships', 'create_final_nodes'],
                'create_final_text_units': ['join_text_units_to_relationship_ids', 'join_text_units_to_entity_ids',
                                            'create_base_text_units'],
                'create_base_documents': ['create_final_text_units'],
                'create_final_documents': ['create_base_documents'],
                }

# 展示工作流之间的拓扑结构
dependencies_graph = nx.DiGraph()

for workflow, deps in dependencies.items():
    dependencies_graph.add_node(workflow)
    for dep in deps:
        dependencies_graph.add_edge(dep, workflow)

dependencies_vis = Network(notebook=True, cdn_resources='remote', directed=True)
dependencies_vis.from_nx(dependencies_graph)
dependencies_vis.show("workflow_dependencies.html")
# Out:
# workflow_dependencies.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="workflow_dependencies.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# 原始文本切片的结果
# document_ids 是原始文本文件的id
# chunk_id 是切片的id
df21 = pd.read_parquet(path_prefix + "create_base_text_units.parquet")
df21
# Out:
#                                  id  \
# 0  1fae6f3d55b5cb0dba1f89f668218cd2
# 1  355e705881fd7c83e813a83d24db74b7
# 2  dee20f36e11c4185c682fd582d02ed69
# 3  5d3d851e7c8a5cea251f64785f55435d
# 4  07730a19b8110138a785adc20fce8020
# 5  b2c9b122d0e796bb26d85487fdaae53a
# 6  138b67752488e94c5e5a9d788efce181
#
#                                                chunk  \
# 0  鲁镇的酒店的格局，是和别处不同的：都是当街一个尺形的大柜台，柜里面预备着热水，可以随时温酒。...
# 1  了这事。幸亏荐头的情面大，辞退不得，便改为专管温酒的一种无聊职务了。\n\n我从此便整天的站...
# 2  东西了!”孔乙己睁大眼睛说，“你怎么这样凭空污人清白……”“什么清白?我前天亲眼见你偷了何家...
# 3  渐复了原，旁人便又问道，“孔乙己，你当真认识字么?”孔乙己看着问他的人，显出不屑置辩的神气。...
# 4  �的答他道，“谁要你教，不是草头底下一个来回的回字么?”孔乙己显出极高兴的样子，将两个指头的...
# 5  …他打折了腿了。”掌柜说，“哦!”“他总仍旧是偷。这一回，是自己发昏，竟偷到丁举人家里去了。...
# 6  ��要好。”掌柜仍然同平常一样，笑着对他说，“孔乙己，你又偷了东西了!”但他这回却不十分分辩...
#
#                            chunk_id                        document_ids  \
# 0  1fae6f3d55b5cb0dba1f89f668218cd2  [129084b0fa1815780605fa5c38c85b77]
# 1  355e705881fd7c83e813a83d24db74b7  [129084b0fa1815780605fa5c38c85b77]
# 2  dee20f36e11c4185c682fd582d02ed69  [129084b0fa1815780605fa5c38c85b77]
# 3  5d3d851e7c8a5cea251f64785f55435d  [129084b0fa1815780605fa5c38c85b77]
# 4  07730a19b8110138a785adc20fce8020  [129084b0fa1815780605fa5c38c85b77]
# 5  b2c9b122d0e796bb26d85487fdaae53a  [129084b0fa1815780605fa5c38c85b77]
# 6  138b67752488e94c5e5a9d788efce181  [129084b0fa1815780605fa5c38c85b77]
#
#    n_tokens
# 0       600
# 1       600
# 2       600
# 3       600
# 4       600
# 5       600
# 6       408

# %%
# 对文本切片进行实体提取的结果
# source_id表示来源文本切片的id
# 同一实体可能在多个文本切片中出现过，因此source_id不唯一
# 多次出现的同一实体，每次被提取时的description会被汇总到一个list中，之后会进行总结
df31 = pd.read_parquet(path_prefix + "create_base_extracted_entities.parquet")
df31
# Out:
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...

# %%
graph_file31 = io.StringIO(df31["entity_graph"][0])
graph31 = nx.read_graphml(graph_file31)
net_vis31 = Network(notebook=True, cdn_resources='remote')
for node, node_data in graph31.nodes(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in node_data.items()])
    title = f"Node: {node}\n\n{attr_text}"
    # 根据node_data中的type属性["ORGANIZATION","PERSON","GEO","EVENT"]，设置不同的颜色
    entity_type = node_data.get("type", "")
    if entity_type == '"ORGANIZATION"':
        net_vis31.add_node(node, title=title, label=node, color="#FFA500")
    elif entity_type == '"PERSON"':
        net_vis31.add_node(node, title=title, label=node, color="#00FF00")
    elif entity_type == '"GEO"':
        net_vis31.add_node(node, title=title, label=node, color="#0000FF")
    elif entity_type == '"EVENT"':
        net_vis31.add_node(node, title=title, label=node, color="#FF0000")
    else:
        net_vis31.add_node(node, title=title, label=node)

    net_vis31.add_node(node, title=title, label=node)

for source, target, edge_data in graph31.edges(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in edge_data.items()])
    title = f"Edge from {source} to {target}\n\n{attr_text}"
    # 根据edge_data中的weight属性数值大小，设置不同的颜色
    edge_weight = edge_data.get("weight", 0)
    if edge_weight > 2:
        net_vis31.add_edge(source, target, title=title, color="#FF0000")
    elif edge_weight > 1:
        net_vis31.add_edge(source, target, title=title, color="#00FF00")
    else:
        net_vis31.add_edge(source, target, title=title)
    net_vis31.add_edge(source, target, title=title)

net_vis31.show("create_base_extracted_entities.html")
# Out:
# create_base_extracted_entities.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="create_base_extracted_entities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# 将同一实体的多个描述进行总结，得到一个综合的描述
df32 = pd.read_parquet(path_prefix + "create_summarized_entities.parquet")
df32
# Out:
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...

# %%
graph_file32 = io.StringIO(df32["entity_graph"][0])
graph32 = nx.read_graphml(graph_file32)
net_vis32 = Network(notebook=True, cdn_resources='remote')
for node, node_data in graph32.nodes(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in node_data.items()])
    title = f"Node: {node}\n\n{attr_text}"
    # 根据node_data中的type属性["ORGANIZATION","PERSON","GEO","EVENT"]，设置不同的颜色
    entity_type = node_data.get("type", "")
    if entity_type == '"ORGANIZATION"':
        net_vis32.add_node(node, title=title, label=node, color="#FFA500")
    elif entity_type == '"PERSON"':
        net_vis32.add_node(node, title=title, label=node, color="#00FF00")
    elif entity_type == '"GEO"':
        net_vis32.add_node(node, title=title, label=node, color="#0000FF")
    elif entity_type == '"EVENT"':
        net_vis32.add_node(node, title=title, label=node, color="#FF0000")
    else:
        net_vis32.add_node(node, title=title, label=node)

    net_vis32.add_node(node, title=title, label=node)

for source, target, edge_data in graph32.edges(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in edge_data.items()])
    title = f"Edge from {source} to {target}\n\n{attr_text}"
    # 根据edge_data中的weight属性数值大小，设置不同的颜色
    edge_weight = edge_data.get("weight", 0)
    if edge_weight > 2:
        net_vis32.add_edge(source, target, title=title, color="#FF0000")
    elif edge_weight > 1:
        net_vis32.add_edge(source, target, title=title, color="#00FF00")
    else:
        net_vis32.add_edge(source, target, title=title)
    net_vis32.add_edge(source, target, title=title)

net_vis32.show("create_summarized_entities.html")
# Out:
# create_summarized_entities.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="create_summarized_entities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# 经过分层莱顿算法，进行分层和社区划分之后的图
# df33每一行是，图的一个层次，一层中包含若干个社区
# 高层次中的社区，是对上一层社区的进一步划分，例如：
# 层次0包含社区0和社区1，层次1包含社区2和社区3
# 层次1社区2 和 层次1社区3 中的实体都来自 层次0社区1
df33 = pd.read_parquet(path_prefix + "create_base_entity_graph.parquet")
df33
# Out:
#    level                                    clustered_graph  \
# 0      0  <graphml xmlns="http://graphml.graphdrawing.or...
# 1      1  <graphml xmlns="http://graphml.graphdrawing.or...
#
#                                           embeddings
# 0  {'"丁举人"': [0.002083270810544491, -0.0186006743...
# 1  {'"丁举人"': [0.002083270810544491, -0.0186006743...

# %%
graph_file330 = io.StringIO(df33["clustered_graph"][0])
graph330 = nx.read_graphml(graph_file330)
net_vis330 = Network(notebook=True, cdn_resources='remote')
for node, node_data in graph330.nodes(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in node_data.items()])
    title = f"Node: {node}\n\n{attr_text}"
    # 只保留第0层次的节点
    entity_level = node_data.get("level", -1)
    if entity_level != 0:
        continue
    # 根据node_data中的cluster属性，设置不同的颜色
    entity_cluster = node_data.get("cluster", "")
    if entity_cluster == '0':
        net_vis330.add_node(node, title=title, label=node, color="#FF0000")
    elif entity_cluster == '1':
        net_vis330.add_node(node, title=title, label=node, color="#00FF00")
    else:
        net_vis330.add_node(node, title=title, label=node, color="#0000FF")

    net_vis330.add_node(node, title=title, label=node)

for source, target, edge_data in graph330.edges(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in edge_data.items()])
    title = f"Edge from {source} to {target}\n\n{attr_text}"
    # 加边之前先判断source和target是否在图中存在，如果不存在则跳过该边
    try:
        net_vis330.get_node(source)
        net_vis330.get_node(target)
    except KeyError:
        continue
    # 根据edge_data中的weight属性数值大小，设置不同的颜色
    edge_weight = edge_data.get("weight", 0)
    if edge_weight > 3:
        net_vis330.add_edge(source, target, title=title, color="#FFA500")
    elif edge_weight > 1:
        net_vis330.add_edge(source, target, title=title, color="#00FF00")
    else:
        net_vis330.add_edge(source, target, title=title)
    net_vis330.add_edge(source, target, title=title)

net_vis330.show("create_base_entity_graph_0.html")
# Out:
# create_base_entity_graph_0.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="create_base_entity_graph_0.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
graph_file331 = io.StringIO(df33["clustered_graph"][1])
graph331 = nx.read_graphml(graph_file331)
net_vis331 = Network(notebook=True, cdn_resources='remote')
for node, node_data in graph331.nodes(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in node_data.items()])
    title = f"Node: {node}\n\n{attr_text}"
    # 只保留第1层次的节点
    entity_level = node_data.get("level", -1)
    if entity_level != 1:
        continue
    # 根据node_data中的cluster属性，设置不同的颜色
    entity_cluster = node_data.get("cluster", "")
    if entity_cluster == '2':
        net_vis331.add_node(node, title=title, label=node, color="#FFA500")
    elif entity_cluster == '3':
        net_vis331.add_node(node, title=title, label=node, color="#00FFA5")
    else:
        net_vis331.add_node(node, title=title, label=node, color="#0000FF")

    net_vis331.add_node(node, title=title, label=node)

for source, target, edge_data in graph331.edges(data=True):
    attr_text = "\n\n".join([f"{key}: {value}" for key, value in edge_data.items()])
    title = f"Edge from {source} to {target}\n\n{attr_text}"
    # 加边之前先判断source和target是否在图中存在，如果不存在则跳过该边
    try:
        net_vis331.get_node(source)
        net_vis331.get_node(target)
    except KeyError:
        continue
    # 根据edge_data中的weight属性数值大小，设置不同的颜色
    edge_weight = edge_data.get("weight", 0)
    if edge_weight > 2:
        net_vis331.add_edge(source, target, title=title, color="#FF0000")
    elif edge_weight > 1:
        net_vis331.add_edge(source, target, title=title, color="#00FF00")
    else:
        net_vis331.add_edge(source, target, title=title)
    net_vis331.add_edge(source, target, title=title)

net_vis331.show("create_base_entity_graph_1.html")
# Out:
# create_base_entity_graph_1.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="create_base_entity_graph_1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# 汇总整理每个实体的信息
# 并且加入基于node2vec的节点embedding、实体名embedding、描述embedding
df34 = pd.read_parquet(path_prefix + "create_final_entities.parquet")
df34
# Out:
#                                   id     name            type  \
# 0   b45241d70f0e43fca764df95b2b81f77     "鲁镇"           "GEO"
# 1   4119fd06010c494caa07f439b333f4c5   "咸亨酒店"  "ORGANIZATION"
# 2   d3835bf3dda84ead99deadbeac5d0d7d    "短衣帮"        "PERSON"
# 3   077d2820ae1845bcbb1803379a3d1eae   "长衫主顾"        "PERSON"
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac      "我"        "PERSON"
# 5   19a7f254a5d64566ab5cc15472df02de     "掌柜"        "PERSON"
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e    "丁举人"        "PERSON"
# 7   f7e11b0e297a44a896dc67928368f600    "孩子们"        "PERSON"
# 8   1fd3fa8bb5a2408790042ab9573779ee     "酒客"        "PERSON"
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c     "碗碟"        "OBJECT"
# 10  e1fd0e904a53409aada44442f23a51cb    "茴香豆"        "OBJECT"
# 11  de988724cfdf45cebfba3b13c43ceede     "柜台"      "LOCATION"
# 12  96aad7cb4b7d40e9b7e13b94a67af206     "店堂"      "LOCATION"
# 13  c9632a35146940c2a86167c7726d35e9     "后院"      "LOCATION"
# 14  9646481f66ce4fd2b08c2eddda42fc82    "孔乙己"            None
# 15  d91a266f766b4737a06b0fda588ba40b     "主顾"        "PERSON"
# 16  bc0e3f075a4c4ebbb7c7b152b65a5625     "酒店"  "ORGANIZATION"
# 17  254770028d7a4fa9877da4ba0ad5ad21     "温酒"         "EVENT"
# 18  4a67211867e5464ba45126315a122a8a     "长衫"        "OBJECT"
# 19  04dbbb2283b845baaeac0eaf0c34c9da    "读书人"        "PERSON"
# 20  1943f245ee4243bdbfbd2fd619ae824a   "科举考试"         "EVENT"
# 21  273daeec8cad41e6b3e450447db58ee7     "何家"  "ORGANIZATION"
# 22  e69dc259edb944ea9ea41264b9fcfe59    "店内外"           "GEO"
# 23  e2f5735c7d714423a2c4f61ca2644626   "偷书事件"         "EVENT"
# 24  deece7e64b2a4628850d4bb6e394a9c3    "长衫客"  "PERSON_GROUP"
# 25  e657b5121ff8456b9a610cfaead8e0cb   "科举制度"       "CONCEPT"
# 26  bf4e255cdac94ccc83a56435a5e4b075   "众人哄笑"         "EVENT"
# 27  3b040bcc19f14e04880ae52881a89c1c   "断腿事件"         "EVENT"
# 28  3d6b216c14354332b1bf1927ba168986  "读书人形象"       "CONCEPT"
# 29  1c109cfdc370463eb6d537e5b7b382fb   "邻舍孩子"        "PERSON"
# 30  3d0dcbc8971b415ea18065edc4d8c8ef     "中秋"         "EVENT"
# 31  68105770b523412388424d984e711917   "喝酒的人"            None
# 32  85c79fd84f5e4f918471c386852204c5   "笔墨纸砚"          "ITEM"
# 33  eae4259b19a741ab9f9f6af18c4a0470     "秀才"        "PERSON"
# 34  3138f39f2bcd43a69e0697cd3b05bc4d     "初冬"           "GEO"
# 35  dde131ab575d44dbb55289a6972be18f     "年关"         "EVENT"
# 36  de9e343f2e334d88a8ac7f8813a915e5     "端午"         "EVENT"
#
#                                           description  human_readable_id  \
# 0   鲁镇是一个充满浓厚地方特色和独特社会结构的背景小镇。在这个地方，酒店的布局独具一格，反映了当...                  0
# 1   咸亨酒店是鲁镇一家著名的酒店，既是故事发生的具体地点，也是背景场所。它是一个充满人间百态和市...                  1
# 2   "短衣帮"是指一群做工的普通劳动者，他们通常在酒店外面站着喝酒，消费较为节俭。这些劳动者与穿...                  2
# 3   "长衫主顾"是指那些穿着长衫的顾客，他们通常较为富裕，具有较高的消费能力。在酒店环境中，长衫...                  3
# 4                   "我是咸亨酒店的一名伙计，从十二岁起在酒店工作，负责温酒等事务。"                  4
# 5   掌柜是咸亨酒店的老板或管理者，负责监督酒店的运营、员工的工作以及日常管理事务，包括结账等。他...                  5
# 6   丁举人是鲁镇一个有地位、有权势且富有影响力的人物。他通过科举考试获得了功名，成为社会上层的一...                  6
# 7         "孩子们是鲁镇的一部分居民，他们有时会在咸亨酒店外面聚集，观察或参与酒店内外的活动。"                  7
# 8                   "酒客是指在咸亨酒店喝酒的顾客，包括短衣帮和长衫主顾等不同群体。"                  8
# 9                             "碗碟是咸亨酒店内用于盛放食物和酒水的器皿。"                  9
# 10  茴香豆是咸亨酒店的一种常见小吃，深受顾客喜爱。这种小吃在孔乙己的生活中扮演了重要角色。孔乙己...                 10
# 11                     "柜台是咸亨酒店内部的重要设施，用于顾客点菜、结账等事务。"                 11
# 12                           "店堂是咸亨酒店内供顾客用餐和饮酒的主要区域。"                 12
# 13                  "后院是咸亨酒店的内部区域，通常用于储存物品或进行一些后勤工作。"                 13
# 14  孔乙己是旧社会的一个读书人，未能考取功名，因而受到周围人的嘲笑和轻视。他身材高大，脸色青白，...                 14
# 15                         "主顾是店里的顾客，他们对人没有好声气，气氛压抑。"                 15
# 16  酒店是一个提供酒水服务的场所，同时作为故事发生的背景地点。在这个环境中，人物之间的关系错综复...                 16
# 17                "温酒是孔乙己在酒店里的一项活动，他经常要求温两碗酒并要一碟茴香豆。"                 17
# 18                     "长衫是一种传统的中式长袍，象征着读书人或有身份地位的人。"                 18
# 19  "读书人"是指那些受过教育、懂得文字且有文化的人。孔乙己自认为属于这一群体，他具备一定的学识...                 19
# 20                 "科举考试是中国古代选拔官员的重要制度，孔乙己曾多次参加但未中举。"                 20
# 21                           "何家是孔乙己曾经偷书的对象，具体背景未详述。"                 21
# 22  "店内外"指的是故事中孔乙己所在的地方，描述了他与周围人的互动环境。这个地点不仅是故事发生的...                 22
# 23                      "偷书事件是指孔乙己被指控偷了何家的书，并因此受到惩罚。"                 23
# 24  "长衫客"是店内的一类特殊顾客，通常是有身份地位的人或读书人。他们穿着讲究，尤其以长衫为标志...                 24
# 25  科举制度是中国古代用于选拔官员的重要制度。这一制度通过严格的考试来选拔有才能的人担任政府官职...                 25
# 26           "众人哄笑是孔乙己被问及问题时周围人的反应，这种行为加剧了孔乙己的尴尬和不安。"                 26
# 27               "断腿事件是孔乙己被丁举人打断腿的不幸遭遇，使他在社会中更加孤立无援。"                 27
# 28  "读书人形象代表了像孔乙己这样执着于学问但未能取得成功的知识分子，反映了社会对他们的评价和态度。"                 28
# 29            "邻舍孩子是一群被孔乙己吸引过来的孩子，他们对孔乙己的行为感到好奇并围着他。"                 29
# 30  中秋是中国的传统节日，通常在农历八月十五日庆祝。这一节日在提供的描述中多次被提及，用以标记特...                 30
# 31                                               None                 31
# 32                    "笔墨纸砚是文人常用的书写工具，孔乙己曾用它们写字教人知识。"                 32
# 33                     "秀才是科举制度中的一种功名，孔乙己曾经努力考取但未成功。"                 33
# 34                           "初冬是一个季节描述，表示故事发生的季节背景。"                 34
# 35             "年关是指每年年底的时期，在文中提到两次，用于描述掌柜对孔乙己欠款的提及。"                 35
# 36          "端午是中国的传统节日，在文中用来标记时间，表示掌柜再次提到孔乙己欠款的时间点。"                 36
#
#                                       graph_embedding  \
# 0   [0.0012126521905884147, -0.01631433144211769, ...
# 1   [0.002068893751129508, -0.021418889984488487, ...
# 2   [0.0014271448599174619, -0.018397178500890732,...
# 3   [0.001347171375527978, -0.01570451632142067, 0...
# 4   [0.002342285355553031, -0.017849063500761986, ...
# 5   [0.0016673633363097906, -0.0175942275673151, 0...
# 6   [0.002083270810544491, -0.018600674346089363, ...
# 7   [0.0011556732933968306, -0.013554797507822514,...
# 8   [0.0015726208221167326, -0.015209603123366833,...
# 9   [0.0015572767006233335, -0.014106987044215202,...
# 10  [0.0022281352430582047, -0.01715683937072754, ...
# 11  [0.0016667196759954095, -0.014162572100758553,...
# 12  [0.0019802795723080635, -0.015760760754346848,...
# 13  [0.0012656799517571926, -0.015786100178956985,...
# 14  [0.0025551971048116684, -0.020093241706490517,...
# 15  [0.0007139316876418889, -0.012738789431750774,...
# 16  [0.001240373938344419, -0.01818258687853813, 0...
# 17  [0.0019640654791146517, -0.015220834873616695,...
# 18  [0.001458996208384633, -0.01417666394263506, 0...
# 19  [0.0016575627960264683, -0.01596238650381565, ...
# 20  [0.0009493798133917153, -0.01284280139952898, ...
# 21  [0.0015973953995853662, -0.014687769114971161,...
# 22  [0.0017712995177134871, -0.017168793827295303,...
# 23  [0.0019115536706522107, -0.015542875975370407,...
# 24  [0.0014001597883179784, -0.017288606613874435,...
# 25  [0.0013330042129382491, -0.014957990497350693,...
# 26  [0.0018914842512458563, -0.016692714765667915,...
# 27  [0.002351033966988325, -0.01693715900182724, 0...
# 28  [0.0013911387650296092, -0.014354261569678783,...
# 29  [0.0023225354962050915, -0.016875389963388443,...
# 30  [0.0012921765446662903, -0.015161988325417042,...
# 31  [0.0019823836628347635, -0.015301073901355267,...
# 32  [0.0018167212838307023, -0.016923651099205017,...
# 33  [0.0019483972573652864, -0.015298962593078613,...
# 34  [0.0013473564758896828, -0.015686839818954468,...
# 35  [0.0010946310358121991, -0.015775222331285477,...
# 36  [0.0013871905393898487, -0.014346584677696228,...
#
#                                         text_unit_ids  \
# 0   [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 1   [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 2   [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 3   [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 4                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 5   [07730a19b8110138a785adc20fce8020, 138b6775248...
# 6   [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 7                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 8                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 9                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 10  [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 11                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 12                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 13                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 14  [07730a19b8110138a785adc20fce8020, 138b6775248...
# 15                 [355e705881fd7c83e813a83d24db74b7]
# 16  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 17                 [355e705881fd7c83e813a83d24db74b7]
# 18                 [355e705881fd7c83e813a83d24db74b7]
# 19  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 20                 [355e705881fd7c83e813a83d24db74b7]
# 21                 [dee20f36e11c4185c682fd582d02ed69]
# 22  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 23                 [dee20f36e11c4185c682fd582d02ed69]
# 24  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 25  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 26                 [5d3d851e7c8a5cea251f64785f55435d]
# 27                 [5d3d851e7c8a5cea251f64785f55435d]
# 28                 [5d3d851e7c8a5cea251f64785f55435d]
# 29                 [07730a19b8110138a785adc20fce8020]
# 30  [07730a19b8110138a785adc20fce8020, 138b6775248...
# 31                 [07730a19b8110138a785adc20fce8020]
# 32                 [07730a19b8110138a785adc20fce8020]
# 33                 [07730a19b8110138a785adc20fce8020]
# 34                 [b2c9b122d0e796bb26d85487fdaae53a]
# 35                 [138b67752488e94c5e5a9d788efce181]
# 36                 [138b67752488e94c5e5a9d788efce181]
#
#                                        name_embedding  \
# 0   [-0.0735669955611229, 0.09959721565246582, -0....
# 1   [-0.022785751149058342, -0.0065047163516283035...
# 2   [-0.06655868887901306, 0.019998403266072273, -...
# 3   [-0.06811540573835373, 0.02075207605957985, -0...
# 4   [-0.04335128888487816, 0.0332072377204895, -0....
# 5   [-0.035059791058301926, 0.01561013888567686, -...
# 6   [-0.03734252229332924, 0.0145729286596179, -0....
# 7   [-0.03457967936992645, 0.03139243647456169, -0...
# 8   [-0.08454140275716782, 0.036982156336307526, -...
# 9   [-0.03174711763858795, 0.05417044833302498, -0...
# 10  [-0.054153166711330414, 0.027801167219877243, ...
# 11  [-0.010142885148525238, 0.006097456905990839, ...
# 12  [-0.08220316469669342, 0.03423191234469414, -0...
# 13  [-0.05810840427875519, 0.02901541069149971, -0...
# 14  [-0.014444270171225071, 0.03999951854348183, -...
# 15  [-0.08531849831342697, 0.044341158121824265, -...
# 16  [-0.03930898755788803, 0.02359311655163765, -0...
# 17  [-0.04950994625687599, 0.06438581645488739, -0...
# 18  [-0.047972485423088074, 0.01356550958007574, -...
# 19  [-0.05982331931591034, 0.013584633357822895, -...
# 20  [-0.02594524435698986, 0.0562015101313591, -0....
# 21  [-0.028475996106863022, 0.028611503541469574, ...
# 22  [-0.05590220168232918, 0.034646689891815186, -...
# 23  [-0.04236514866352081, 0.00416989391669631, -0...
# 24  [-0.06599810719490051, 0.00044924451503902674,...
# 25  [-0.042407821863889694, 0.03999017924070358, -...
# 26  [-0.048480719327926636, 0.04908958077430725, -...
# 27  [-0.034880638122558594, 0.0015311033930629492,...
# 28  [-0.0701027363538742, -0.006173373199999332, -...
# 29  [-0.0157120693475008, 0.08741412311792374, -0....
# 30  [-0.013469027355313301, 0.06138564646244049, -...
# 31  [-0.050636447966098785, 0.04222230985760689, -...
# 32  [-0.04981321841478348, 0.06454353779554367, -0...
# 33  [-0.04797440394759178, 0.055066268891096115, -...
# 34  [-0.024692345410585403, 0.0664350837469101, -0...
# 35  [-0.05182651802897453, 0.07243271172046661, -0...
# 36  [-0.010830613784492016, 0.06212705001235008, -...
#
#                                 description_embedding
# 0   [-0.055016759783029556, 0.031515203416347504, ...
# 1   [-0.012898093089461327, 0.013879787176847458, ...
# 2   [-0.06994222104549408, 0.003092781640589237, -...
# 3   [-0.0612790621817112, -0.025796692818403244, -...
# 4   [-0.024990806356072426, 0.0028743341099470854,...
# 5   [-0.017183413729071617, -0.029239201918244362,...
# 6   [-0.028294086456298828, 0.04944520816206932, -...
# 7   [-0.013658163137733936, 0.014908626675605774, ...
# 8   [-0.05934860184788704, -0.005974501371383667, ...
# 9   [0.005624593701213598, 0.017494555562734604, -...
# 10  [-0.029842961579561234, -0.008601794950664043,...
# 11  [0.026671117171645164, -0.01785074733197689, -...
# 12  [-0.024523425847291946, 0.005394203122705221, ...
# 13  [-0.022499768063426018, -0.02406681887805462, ...
# 14  [-0.01936291716992855, 0.019194714725017548, -...
# 15  [-0.05719323456287384, 0.02025190368294716, -0...
# 16  [-0.011936872266232967, 0.019466733559966087, ...
# 17  [0.0010459822369739413, 0.05408421903848648, -...
# 18  [-0.029567943885922432, 0.012709715403616428, ...
# 19  [-0.0424274243414402, 0.008685465902090073, -0...
# 20  [-0.03051752597093582, 0.050143007189035416, -...
# 21  [-0.01568717136979103, 0.0459846556186676, -0....
# 22  [-0.040805384516716, 0.028105033561587334, -0....
# 23  [-0.007915369234979153, 0.024228928610682487, ...
# 24  [-0.058533962815999985, -0.03706248104572296, ...
# 25  [-0.026262935250997543, 0.03644206002354622, -...
# 26  [-0.0037445800844579935, 0.052346110343933105,...
# 27  [-0.002594820922240615, 0.033337753266096115, ...
# 28  [-0.05152801424264908, -0.008880550041794777, ...
# 29  [0.022341230884194374, 0.07790188491344452, -0...
# 30  [-0.029386043548583984, 0.03293970599770546, -...
# 31  [-0.050636447966098785, 0.04222230985760689, -...
# 32  [-0.03695462644100189, 0.07891810685396194, -0...
# 33  [-0.016917750239372253, 0.07259467244148254, -...
# 34  [-0.044579166918992996, 0.046485256403684616, ...
# 35  [-0.030964618548750877, 0.044735413044691086, ...
# 36  [-0.02256867289543152, 0.044551149010658264, -...

# %%
# 汇总各个节点的信息
# 并根据node2vec的embedding结果，调用UMAP降维算法，生成各节点2维可视化时的坐标
# 同一节点可能在不同层中多次出现，因此这里的表格长度是 节点数 * 层次数
df35 = pd.read_parquet(path_prefix + "create_final_nodes.parquet")
df35
# Out:
#     level   title            type  \
# 0       0    "鲁镇"           "GEO"
# 1       0  "咸亨酒店"  "ORGANIZATION"
# 2       0   "短衣帮"        "PERSON"
# 3       0  "长衫主顾"        "PERSON"
# 4       0     "我"        "PERSON"
# ..    ...     ...             ...
# 69      1  "笔墨纸砚"          "ITEM"
# 70      1    "秀才"        "PERSON"
# 71      1    "初冬"           "GEO"
# 72      1    "年关"         "EVENT"
# 73      1    "端午"         "EVENT"
#
#                                           description  \
# 0   鲁镇是一个充满浓厚地方特色和独特社会结构的背景小镇。在这个地方，酒店的布局独具一格，反映了当...
# 1   咸亨酒店是鲁镇一家著名的酒店，既是故事发生的具体地点，也是背景场所。它是一个充满人间百态和市...
# 2   "短衣帮"是指一群做工的普通劳动者，他们通常在酒店外面站着喝酒，消费较为节俭。这些劳动者与穿...
# 3   "长衫主顾"是指那些穿着长衫的顾客，他们通常较为富裕，具有较高的消费能力。在酒店环境中，长衫...
# 4                   "我是咸亨酒店的一名伙计，从十二岁起在酒店工作，负责温酒等事务。"
# ..                                                ...
# 69                    "笔墨纸砚是文人常用的书写工具，孔乙己曾用它们写字教人知识。"
# 70                     "秀才是科举制度中的一种功名，孔乙己曾经努力考取但未成功。"
# 71                           "初冬是一个季节描述，表示故事发生的季节背景。"
# 72             "年关是指每年年底的时期，在文中提到两次，用于描述掌柜对孔乙己欠款的提及。"
# 73          "端午是中国的传统节日，在文中用来标记时间，表示掌柜再次提到孔乙己欠款的时间点。"
#
#                                             source_id community  degree  \
# 0   07730a19b8110138a785adc20fce8020,1fae6f3d55b5c...         1       2
# 1   07730a19b8110138a785adc20fce8020,1fae6f3d55b5c...         1      14
# 2   07730a19b8110138a785adc20fce8020,1fae6f3d55b5c...         1       3
# 3   07730a19b8110138a785adc20fce8020,1fae6f3d55b5c...         1       2
# 4                    1fae6f3d55b5cb0dba1f89f668218cd2         1       2
# ..                                                ...       ...     ...
# 69                   07730a19b8110138a785adc20fce8020      None       1
# 70                   07730a19b8110138a785adc20fce8020      None       1
# 71                   b2c9b122d0e796bb26d85487fdaae53a      None       1
# 72                   138b67752488e94c5e5a9d788efce181      None       1
# 73                   138b67752488e94c5e5a9d788efce181      None       1
#
#     human_readable_id                                id  size  \
# 0                   0  b45241d70f0e43fca764df95b2b81f77     2
# 1                   1  4119fd06010c494caa07f439b333f4c5    14
# 2                   2  d3835bf3dda84ead99deadbeac5d0d7d     3
# 3                   3  077d2820ae1845bcbb1803379a3d1eae     2
# 4                   4  3671ea0dd4e84c1a9b02c5ab2c8f4bac     2
# ..                ...                               ...   ...
# 69                 32  85c79fd84f5e4f918471c386852204c5     1
# 70                 33  eae4259b19a741ab9f9f6af18c4a0470     1
# 71                 34  3138f39f2bcd43a69e0697cd3b05bc4d     1
# 72                 35  dde131ab575d44dbb55289a6972be18f     1
# 73                 36  de9e343f2e334d88a8ac7f8813a915e5     1
#
#                                       graph_embedding  \
# 0   [0.0012126521905884147, -0.01631433144211769, ...
# 1   [0.002068893751129508, -0.021418889984488487, ...
# 2   [0.0014271448599174619, -0.018397178500890732,...
# 3   [0.001347171375527978, -0.01570451632142067, 0...
# 4   [0.002342285355553031, -0.017849063500761986, ...
# ..                                                ...
# 69  [0.0018167212838307023, -0.016923651099205017,...
# 70  [0.0019483972573652864, -0.015298962593078613,...
# 71  [0.0013473564758896828, -0.015686839818954468,...
# 72  [0.0010946310358121991, -0.015775222331285477,...
# 73  [0.0013871905393898487, -0.014346584677696228,...
#
#                    top_level_node_id          x          y
# 0   b45241d70f0e43fca764df95b2b81f77 -31.406649 -19.495066
# 1   4119fd06010c494caa07f439b333f4c5  15.223695   4.372850
# 2   d3835bf3dda84ead99deadbeac5d0d7d  17.560656   5.461694
# 3   077d2820ae1845bcbb1803379a3d1eae  22.915752  24.380701
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac  16.253996   4.803540
# ..                               ...        ...        ...
# 69  85c79fd84f5e4f918471c386852204c5  23.272655  24.090113
# 70  eae4259b19a741ab9f9f6af18c4a0470   4.452078  12.036289
# 71  3138f39f2bcd43a69e0697cd3b05bc4d   2.766302   9.519711
# 72  dde131ab575d44dbb55289a6972be18f   3.723950  11.748106
# 73  de9e343f2e334d88a8ac7f8813a915e5   3.767946  15.776850
#
# [74 rows x 14 columns]

# %%
# 整理汇总社区划分的结果
df41 = pd.read_parquet(path_prefix + "create_final_communities.parquet")
df41
# Out:
#   id        title  level raw_community  \
# 0  1  Community 1      0             1
# 1  0  Community 0      0             0
# 2  3  Community 3      1             3
# 3  2  Community 2      1             2
#
#                                     relationship_ids  \
# 0  [e2bf260115514fb3b252fd879fb3e7be, b462b94ce47...
# 1  [b785a9025069417f94950ad231bb1441, 3b6cd96a273...
# 2  [e2bf260115514fb3b252fd879fb3e7be, b462b94ce47...
# 3  [17ed1d92075643579a712cc6c29e8ddb, 3ce7c210a21...
#
#                                        text_unit_ids
# 0  [07730a19b8110138a785adc20fce8020,1fae6f3d55b5...
# 1  [07730a19b8110138a785adc20fce8020,138b67752488...
# 2  [07730a19b8110138a785adc20fce8020,1fae6f3d55b5...
# 3  [07730a19b8110138a785adc20fce8020,1fae6f3d55b5...

# %%
# 记录每个文本片段中提取出了哪些实体
df23 = pd.read_parquet(path_prefix + "join_text_units_to_entity_ids.parquet")
df23
# Out:
#                       text_unit_ids  \
# 0  07730a19b8110138a785adc20fce8020
# 1  1fae6f3d55b5cb0dba1f89f668218cd2
# 2  355e705881fd7c83e813a83d24db74b7
# 3  5d3d851e7c8a5cea251f64785f55435d
# 4  dee20f36e11c4185c682fd582d02ed69
# 5  138b67752488e94c5e5a9d788efce181
# 6  b2c9b122d0e796bb26d85487fdaae53a
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [4119fd06010c494caa07f439b333f4c5, d3835bf3dda...
# 3  [4119fd06010c494caa07f439b333f4c5, 19a7f254a5d...
# 4  [4119fd06010c494caa07f439b333f4c5, d3835bf3dda...
# 5  [19a7f254a5d64566ab5cc15472df02de, 9646481f66c...
# 6  [19a7f254a5d64566ab5cc15472df02de, e7ffaee9d31...
#
#                                  id
# 0  07730a19b8110138a785adc20fce8020
# 1  1fae6f3d55b5cb0dba1f89f668218cd2
# 2  355e705881fd7c83e813a83d24db74b7
# 3  5d3d851e7c8a5cea251f64785f55435d
# 4  dee20f36e11c4185c682fd582d02ed69
# 5  138b67752488e94c5e5a9d788efce181
# 6  b2c9b122d0e796bb26d85487fdaae53a

# %%
# 整理汇总实体间关系，即边的信息
# 并且加入对描述的embedding结果
df36 = pd.read_parquet(path_prefix + "create_final_relationships.parquet")
df36
# Out:
#     source   target  weight  \
# 0     "鲁镇"   "咸亨酒店"     1.0
# 1     "鲁镇"     "酒店"     1.0
# 2   "咸亨酒店"    "短衣帮"     1.0
# 3   "咸亨酒店"   "长衫主顾"     1.0
# 4   "咸亨酒店"      "我"     1.0
# 5   "咸亨酒店"     "掌柜"     1.0
# 6   "咸亨酒店"    "孩子们"     1.0
# 7   "咸亨酒店"     "酒客"     1.0
# 8   "咸亨酒店"     "碗碟"     1.0
# 9   "咸亨酒店"    "茴香豆"     1.0
# 10  "咸亨酒店"     "柜台"     1.0
# 11  "咸亨酒店"     "店堂"     1.0
# 12  "咸亨酒店"     "后院"     1.0
# 13  "咸亨酒店"    "孔乙己"     3.0
# 14  "咸亨酒店"   "众人哄笑"     1.0
# 15   "短衣帮"    "孔乙己"     2.0
# 16   "短衣帮"     "酒店"     1.0
# 17  "长衫主顾"     "酒店"     1.0
# 18     "我"     "掌柜"     1.0
# 19    "掌柜"    "孔乙己"     7.0
# 20   "丁举人"    "孔乙己"     6.0
# 21   "茴香豆"    "孔乙己"     4.0
# 22   "孔乙己"     "酒店"     2.0
# 23   "孔乙己"     "主顾"     1.0
# 24   "孔乙己"     "温酒"     1.0
# 25   "孔乙己"     "长衫"     1.0
# 26   "孔乙己"    "读书人"     2.0
# 27   "孔乙己"   "科举考试"     1.0
# 28   "孔乙己"     "何家"     1.0
# 29   "孔乙己"    "店内外"     2.0
# 30   "孔乙己"   "偷书事件"     1.0
# 31   "孔乙己"    "长衫客"     2.0
# 32   "孔乙己"   "科举制度"     2.0
# 33   "孔乙己"   "众人哄笑"     1.0
# 34   "孔乙己"   "断腿事件"     1.0
# 35   "孔乙己"  "读书人形象"     1.0
# 36   "孔乙己"   "邻舍孩子"     1.0
# 37   "孔乙己"   "喝酒的人"     1.0
# 38   "孔乙己"   "笔墨纸砚"     1.0
# 39   "孔乙己"     "秀才"     1.0
# 40   "孔乙己"     "中秋"     2.0
# 41   "孔乙己"     "初冬"     1.0
# 42   "孔乙己"     "年关"     1.0
# 43   "孔乙己"     "端午"     1.0
#
#                                           description  \
# 0               "咸亨酒店位于鲁镇，是当地居民日常生活中的一部分，反映了鲁镇的社会结构。"
# 1                              "酒店位于鲁镇，是镇上的一个重要社交场所。"
# 2           "短衣帮是咸亨酒店的主要顾客之一，他们在酒店外面喝酒，形成了酒店的一种典型景象。"
# 3        "长衫主顾是咸亨酒店的重要顾客，他们在店内享受更高档次的服务，受到酒店掌柜的特别关注。"
# 4                "我在咸亨酒店担任伙计，负责温酒等事务，经历了酒店内外的不同顾客群体。"
# 5                      "掌柜是咸亨酒店的管理者，负责监督酒店的运营和员工的工作。"
# 6                     "孩子们常常在咸亨酒店外面玩耍或围观，增加了酒店周围的活力。"
# 7             "酒客们构成了咸亨酒店的主要顾客群体，他们的行为和习惯反映了鲁镇的社会风貌。"
# 8                       "碗碟是咸亨酒店日常运营中不可或缺的用具，用于服务顾客。"
# 9                           "茴香豆是咸亨酒店提供给顾客的一种受欢迎的小吃。"
# 10                  "柜台是咸亨酒店内部重要的服务设施，用于接待顾客和处理各种事务。"
# 11                       "店堂是咸亨酒店的主要营业区域，顾客在这里用餐和饮酒。"
# 12                   "后院是咸亨酒店的后勤区域，用于储存物品和进行其他支持性工作。"
# 13  咸亨酒店是孔乙己经常光顾的地方，他在那里喝酒、吃茴香豆，并与其他人互动。然而，咸亨酒店也是孔...
# 14              "咸亨酒店是众人哄笑的主要场所，这里的氛围充满了对孔乙己的嘲讽和不尊重。"
# 15  孔乙己是一个经常出现在店里的人物，与短衣帮有互动。短衣帮是一群态度轻蔑的人，他们常常嘲笑孔乙...
# 16                           "短衣帮是酒店的常客，他们通常站在柜台前喝酒。"
# 17                  "长衫主顾是酒店的另一类顾客，他们坐在室内喝酒并享受更好的服务。"
# 18                         "掌柜对我进行了工作安排和调整，最终让我专管温酒。"
# 19  掌柜与孔乙己之间存在一种复杂而不平等的关系。掌柜经常通过问孔乙己问题来引人发笑，显示出对他的...
# 20  丁举人和孔乙己是两个社会地位截然不同的个体，他们的互动深刻地反映了科举制度下社会阶层的差异及...
# 21  孔乙己是一位喜欢茴香豆的人物，这种食物在他的生活中扮演了多重角色。他不仅自己喜欢吃茴香豆，还...
# 22  孔乙己是酒店的常客，他经常在酒店里活动并与其他人互动。然而，他在酒店中的经历并不总是愉快的，...
# 23                          "主顾们常常嘲笑孔乙己，特别是关于他偷书的事情。"
# 24                        "孔乙己到酒店后，总是要求温两碗酒，并要一碟茴香豆。"
# 25                       "孔乙己虽然贫困潦倒，但仍穿着长衫，以显示自己的身份。"
# 26  孔乙己是一个自认为属于读书人行列的人，尽管他未能通过科举考试获得功名。他对自己的学识感到自豪...
# 27                   "孔乙己多次参加科举考试，但始终未能中举，这成为他一生的遗憾。"
# 28                            "孔乙己被指控从何家偷书，导致他受到了惩罚。"
# 29  孔乙己是一个在店内外频繁与他人互动的人物，尤其是在关于他的读书能力和品行的讨论中。然而，这些...
# 30                 "孔乙己因偷书事件而成为众人议论的对象，并且这件事影响了他的声誉。"
# 31  孔乙己试图融入长衫客的群体，但由于贫困和未能进学而被排挤。尽管长衫客没有直接嘲笑孔乙己，但他...
# 32  孔乙己一生致力于追求科举功名，但最终未能如愿以偿。科举制度在当时社会中占据着极其重要的地位，...
# 33                    "孔乙己的回答引发了周围人的哄笑，这使他感到更加尴尬和不安。"
# 34       "断腿事件是孔乙己一生中的重大转折点，使他在社会中更加孤立无援，彻底失去了生存的能力。"
# 35  "孔乙己是典型的读书人形象，他执着于学问却未能取得成功，反映了当时社会对这类知识分子的态度和...
# 36                      "孔乙己给邻舍孩子茴香豆吃，孩子们对他表现出浓厚的兴趣。"
# 37                             "一个喝酒的人透露了孔乙己被打折腿的消息。"
# 38                            "孔乙己常用笔墨纸砚写字，并以此教别人知识。"
# 39                                "孔乙己曾试图考取秀才，但未能如愿。"
# 40  孔乙己的故事发生在中秋过后，这一时间点为故事提供了具体的时间背景。在中秋这个传统的团圆节日里...
# 41               "孔乙己的身体状况在接近初冬时变得更加糟糕，反映出环境对他生活的影响。"
# 42                    "孔乙己在年关时被掌柜提及欠款，暗示了他生活的困顿和不稳定。"
# 43                     "孔乙己在端午时再次被掌柜提及欠款，进一步强调了他的困境。"
#
#                                         text_unit_ids  \
# 0                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 1                  [07730a19b8110138a785adc20fce8020]
# 2                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 3                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 4                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 5                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 6                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 7                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 8                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 9                  [1fae6f3d55b5cb0dba1f89f668218cd2]
# 10                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 11                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 12                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 13  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 14                 [5d3d851e7c8a5cea251f64785f55435d]
# 15  [355e705881fd7c83e813a83d24db74b7, dee20f36e11...
# 16                 [07730a19b8110138a785adc20fce8020]
# 17                 [07730a19b8110138a785adc20fce8020]
# 18                 [1fae6f3d55b5cb0dba1f89f668218cd2]
# 19  [07730a19b8110138a785adc20fce8020, 138b6775248...
# 20  [07730a19b8110138a785adc20fce8020, 1fae6f3d55b...
# 21  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 22  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 23                 [355e705881fd7c83e813a83d24db74b7]
# 24                 [355e705881fd7c83e813a83d24db74b7]
# 25                 [355e705881fd7c83e813a83d24db74b7]
# 26  [07730a19b8110138a785adc20fce8020, 355e705881f...
# 27                 [355e705881fd7c83e813a83d24db74b7]
# 28                 [dee20f36e11c4185c682fd582d02ed69]
# 29  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 30                 [dee20f36e11c4185c682fd582d02ed69]
# 31  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 32  [5d3d851e7c8a5cea251f64785f55435d, dee20f36e11...
# 33                 [5d3d851e7c8a5cea251f64785f55435d]
# 34                 [5d3d851e7c8a5cea251f64785f55435d]
# 35                 [5d3d851e7c8a5cea251f64785f55435d]
# 36                 [07730a19b8110138a785adc20fce8020]
# 37                 [07730a19b8110138a785adc20fce8020]
# 38                 [07730a19b8110138a785adc20fce8020]
# 39                 [07730a19b8110138a785adc20fce8020]
# 40  [138b67752488e94c5e5a9d788efce181, b2c9b122d0e...
# 41                 [b2c9b122d0e796bb26d85487fdaae53a]
# 42                 [138b67752488e94c5e5a9d788efce181]
# 43                 [138b67752488e94c5e5a9d788efce181]
#
#                                   id human_readable_id  \
# 0   e2bf260115514fb3b252fd879fb3e7be                 0
# 1   b462b94ce47a4b8c8fffa33f7242acec                 1
# 2   17ed1d92075643579a712cc6c29e8ddb                 2
# 3   3ce7c210a21b4deebad7cc9308148d86                 3
# 4   d64ed762ea924caa95c8d06f072a9a96                 4
# 5   adf4ee3fbe9b4d0381044838c4f889c8                 5
# 6   32ee140946e5461f9275db664dc541a5                 6
# 7   c160b9cb27d6408ba6ab20214a2f3f81                 7
# 8   23527cd679ff4d5a988d52e7cd056078                 8
# 9   f1c6eed066f24cbdb376b910fce29ed4                 9
# 10  83a6cb03df6b41d8ad6ee5f6fef5f024                10
# 11  147c038aef3e4422acbbc5f7938c4ab8                11
# 12  b7702b90c7f24190b864e8c6e64612a5                12
# 13  de6fa24480894518ab3cbcb66f739266                13
# 14  6fae5ee1a831468aa585a1ea09095998                14
# 15  ef32c4b208d041cc856f6837915dc1b0                15
# 16  07b2425216bd4f0aa4e079827cb48ef5                16
# 17  2670deebfa3f4d69bb82c28ab250a209                17
# 18  404309e89a5241d6bff42c05a45df206                18
# 19  b785a9025069417f94950ad231bb1441                19
# 20  3b6cd96a27304614850709aba1c9598b                20
# 21  d54956b79dd147f894b67a8b97dcbef0                21
# 22  958beecdb5bb4060948415ffd75d2b03                22
# 23  b999ed77e19e4f85b7f1ae79af5c002a                23
# 24  48c0c4d72da74ff5bb926fa0c856d1a7                24
# 25  4f3c97517f794ebfb49c4c6315f9cf23                25
# 26  1745a2485a9443bab76587ad650e9be0                26
# 27  32e6ccab20d94029811127dbbe424c64                27
# 28  94a964c6992945ebb3833dfdfdc8d655                28
# 29  1eb829d0ace042089f0746f78729696c                29
# 30  015e7b58d1a14b44beab3bbc9f912c18                30
# 31  26f88ab3e2e04c33a459ad6270ade565                31
# 32  babe97e1d9784cffa1c85abc1e588126                32
# 33  1033a18c45aa4584b2aef6ab96890351                33
# 34  c9b8ce91fc2945b4907fe35519339cac                34
# 35  fa3c4204421c48609e52c8de2da4c654                35
# 36  53af055f068244d0ac861b2e89376495                36
# 37  c03ab3ce8cb74ad2a03b94723bfab3c7                37
# 38  ed6d2eee9d7b4f5db466b1f6404d31cc                38
# 39  fc01e9baa80e417c9206f941bb279407                39
# 40  56d0e5ebe79e4814bd1463cf6ca21394                40
# 41  7c49f2710e8b4d3b8dc9310834406ea5                41
# 42  c6d1e4f56c2843e89cf0b91c10bb6de2                42
# 43  0adb2d9941f34ef7b2f7743cc6225844                43
#
#                                 description_embedding  source_degree  \
# 0   [-0.02920384146273136, 0.011476426385343075, -...              2
# 1   [-0.034622471779584885, 0.051642268896102905, ...              2
# 2   [-0.035893648862838745, -0.009653432294726372,...             14
# 3   [-0.041586462408304214, -0.03429432585835457, ...             14
# 4   [-0.03252376616001129, -0.020645689219236374, ...             14
# 5   [-0.02783893421292305, -0.04520457610487938, -...             14
# 6   [-0.005404822528362274, -0.017838815227150917,...             14
# 7   [-0.044189728796482086, 0.0047186692245304585,...             14
# 8   [-0.035238996148109436, -0.006586862727999687,...             14
# 9   [-0.03453749045729637, -0.016502296552062035, ...             14
# 10  [0.01486924383789301, -0.023459507152438164, -...             14
# 11  [-0.035733114928007126, -0.0072726053185760975...             14
# 12  [-0.025450672954320908, -0.028915060684084892,...             14
# 13  [-0.014125773683190346, -0.024081360548734665,...             14
# 14  [0.0021800901740789413, -0.0015157395973801613...             14
# 15  [-0.04729603976011276, 0.012369433417916298, -...              3
# 16  [-0.0383291132748127, -0.005414610728621483, -...              3
# 17  [-0.061651088297367096, 0.008307765237987041, ...              2
# 18  [-0.04239332303404808, -0.0006270637968555093,...              2
# 19  [-0.024027977138757706, -0.0085143456235528, -...              3
# 20  [-0.004488072358071804, 0.025196872651576996, ...              1
# 21  [-0.040228258818387985, 0.012649293057620525, ...              2
# 22  [-0.040868569165468216, 0.010924110189080238, ...             27
# 23  [-0.041675958782434464, 0.031926970928907394, ...             27
# 24  [-0.011056235991418362, 0.04703287407755852, -...             27
# 25  [-0.03488173708319664, 0.027461759746074677, -...             27
# 26  [-0.02796270325779915, 0.026798399165272713, -...             27
# 27  [-0.01961677521467209, 0.05095214769244194, -0...             27
# 28  [-0.006213868036866188, 0.04475156590342522, -...             27
# 29  [-0.030674204230308533, 0.00025628405273891985...             27
# 30  [-0.0003422269073780626, 0.03401310369372368, ...             27
# 31  [-0.04551060497760773, 0.02966211549937725, -0...             27
# 32  [-0.022663915529847145, 0.035592202097177505, ...             27
# 33  [0.008807014673948288, 0.04571942239999771, -0...             27
# 34  [0.013418683782219887, 0.03259939327836037, -0...             27
# 35  [-0.04120829328894615, 0.01980254426598549, -0...             27
# 36  [0.017957374453544617, 0.053609900176525116, -...             27
# 37  [-0.0010729612549766898, 0.04068433865904808, ...             27
# 38  [-0.031332485377788544, 0.06200859323143959, -...             27
# 39  [-0.02884223498404026, 0.07003151625394821, -0...             27
# 40  [0.004183901473879814, 0.02847697213292122, -0...             27
# 41  [0.017157316207885742, 0.03663638234138489, -0...             27
# 42  [-0.002163443947210908, 0.01680934801697731, -...             27
# 43  [0.009514831937849522, 0.02856423519551754, -0...             27
#
#     target_degree  rank
# 0              14    16
# 1               4     6
# 2               3    17
# 3               2    16
# 4               2    16
# 5               3    17
# 6               1    15
# 7               1    15
# 8               1    15
# 9               2    16
# 10              1    15
# 11              1    15
# 12              1    15
# 13             27    41
# 14              2    16
# 15             27    30
# 16              4     7
# 17              4     6
# 18              3     5
# 19             27    30
# 20             27    28
# 21             27    29
# 22              4    31
# 23              1    28
# 24              1    28
# 25              1    28
# 26              1    28
# 27              1    28
# 28              1    28
# 29              1    28
# 30              1    28
# 31              1    28
# 32              1    28
# 33              2    29
# 34              1    28
# 35              1    28
# 36              1    28
# 37              1    28
# 38              1    28
# 39              1    28
# 40              1    28
# 41              1    28
# 42              1    28
# 43              1    28

# %%
# 记录每个文本片段中提取出了哪些关系
df24 = pd.read_parquet(path_prefix + "join_text_units_to_relationship_ids.parquet")
df24
# Out:
#                                  id  \
# 0  1fae6f3d55b5cb0dba1f89f668218cd2
# 1  07730a19b8110138a785adc20fce8020
# 2  355e705881fd7c83e813a83d24db74b7
# 3  dee20f36e11c4185c682fd582d02ed69
# 4  5d3d851e7c8a5cea251f64785f55435d
# 5  138b67752488e94c5e5a9d788efce181
# 6  b2c9b122d0e796bb26d85487fdaae53a
#
#                                     relationship_ids
# 0  [e2bf260115514fb3b252fd879fb3e7be, 17ed1d92075...
# 1  [b462b94ce47a4b8c8fffa33f7242acec, de6fa244808...
# 2  [de6fa24480894518ab3cbcb66f739266, ef32c4b208d...
# 3  [de6fa24480894518ab3cbcb66f739266, ef32c4b208d...
# 4  [6fae5ee1a831468aa585a1ea09095998, b785a902506...
# 5  [b785a9025069417f94950ad231bb1441, 56d0e5ebe79...
# 6  [b785a9025069417f94950ad231bb1441, 3b6cd96a273...

# %%
# 汇总每个社区中所有的实体与节点信息
# 并通过大模型进行总结，生成社区报告
df42 = pd.read_parquet(path_prefix + "create_final_community_reports.parquet")
df42
# Out:
#   community                                       full_content  level  rank  \
# 0         2  # 咸亨酒店与鲁镇社会\n\n社区围绕咸亨酒店展开，这里是鲁镇居民日常生活的一部分。咸亨酒店...      1   6.5
# 1         3  # 鲁镇与咸亨酒店的社会结构\n\n该社区围绕鲁镇和咸亨酒店展开，揭示了不同社会阶层之间的互...      1   7.5
# 2         0  # 咸亨酒店与孔乙己的社会处境\n\n社区围绕咸亨酒店展开，这里是孔乙己经常光顾的地方。孔乙...      0   7.5
# 3         1  # 咸亨酒店与鲁镇社区\n\n该社区围绕咸亨酒店展开，这里是鲁镇社会互动的重要场所。咸亨酒店...      0   7.5
#
#            title                                   rank_explanation  \
# 0      咸亨酒店与鲁镇社会       影响严重性评分为中等到高，因为咸亨酒店不仅是商业场所，更是社会互动和文化反映的重要地点。
# 1   鲁镇与咸亨酒店的社会结构  影响严重性评分为较高，因为社区中的互动揭示了深刻的社会不平等和阶级差异，这对理解历史背景下的...
# 2  咸亨酒店与孔乙己的社会处境   影响严重性评分为较高，因为故事深刻反映了社会阶层差异和知识分子的困境，具有重要的文化和社会意义。
# 3      咸亨酒店与鲁镇社区     影响严重程度评分为较高，因为咸亨酒店作为社会互动的核心场所，反映了深刻的社会问题和人物命运。
#
#                                              summary  \
# 0  社区围绕咸亨酒店展开，这里是鲁镇居民日常生活的一部分。咸亨酒店不仅是顾客饮酒用餐的地方，也是...
# 1  该社区围绕鲁镇和咸亨酒店展开，揭示了不同社会阶层之间的互动。酒店不仅是提供酒水服务的场所，还...
# 2  社区围绕咸亨酒店展开，这里是孔乙己经常光顾的地方。孔乙己是一个未能通过科举考试的读书人，因其...
# 3  该社区围绕咸亨酒店展开，这里是鲁镇社会互动的重要场所。咸亨酒店不仅是故事发生的背景地点，还是...
#
#                                             findings  \
# 0  [{'explanation': '咸亨酒店是鲁镇的一个重要地标，不仅为当地居民提供了饮食服...
# 1  [{'explanation': '咸亨酒店是鲁镇的重要社交场所，不仅提供酒水服务，还承载着...
# 2  [{'explanation': '孔乙己是旧社会中一个典型的落魄知识分子，他未能通过科举考...
# 3  [{'explanation': '咸亨酒店是鲁镇社会互动的重要场所，既是故事发生的具体地点...
#
#                                    full_content_json  \
# 0  {\n    "title": "咸亨酒店与鲁镇社会",\n    "summary": "...
# 1  {\n    "title": "鲁镇与咸亨酒店的社会结构",\n    "summary"...
# 2  {\n    "title": "咸亨酒店与孔乙己的社会处境",\n    "summary...
# 3  {\n    "title": "咸亨酒店与鲁镇社区",\n    "summary": "...
#
#                                      id  \
# 0  78bc8883-8a38-4d90-befd-b07efedb4b0b
# 1  d35658cd-e490-4eed-94fd-67702af25376
# 2  eca63876-b512-4ae3-9423-d087e7a2d871
# 3  e395506e-2380-483d-901f-c581e97b1884
#
#                               full_content_embedding  \
# 0  [-0.020747853443026543, -0.025770612061023712,...
# 1  [-0.022673679515719414, -0.009273399598896503,...
# 2  [0.0074726277962327, -0.00654965452849865, -0....
# 3  [-0.015817349776625633, -0.02263767458498478, ...
#
#                                    summary_embedding  \
# 0  [-0.033187586814165115, 0.011210976168513298, ...
# 1  [-0.0254571083933115, 0.022005954757332802, -0...
# 2  [-0.01107996515929699, 0.006226920988410711, -...
# 3  [-0.028807369992136955, 0.00909372791647911, -...
#
#                                      title_embedding
# 0  [-0.023146403953433037, 0.02408142015337944, -...
# 1  [-0.02568134106695652, 0.02306118793785572, -0...
# 2  [-0.00931564811617136, -0.002687018597498536, ...
# 3  [-0.035497359931468964, 0.0266893170773983, -0...

# %%
# 汇总每个文本片段中提取的实体与关系信息
df22 = pd.read_parquet(path_prefix + "create_final_text_units.parquet")
df22
# Out:
#                                  id  \
# 0  1fae6f3d55b5cb0dba1f89f668218cd2
# 1  355e705881fd7c83e813a83d24db74b7
# 2  dee20f36e11c4185c682fd582d02ed69
# 3  5d3d851e7c8a5cea251f64785f55435d
# 4  07730a19b8110138a785adc20fce8020
# 5  b2c9b122d0e796bb26d85487fdaae53a
# 6  138b67752488e94c5e5a9d788efce181
#
#                                                 text  \
# 0  鲁镇的酒店的格局，是和别处不同的：都是当街一个尺形的大柜台，柜里面预备着热水，可以随时温酒。...
# 1  了这事。幸亏荐头的情面大，辞退不得，便改为专管温酒的一种无聊职务了。\n\n我从此便整天的站...
# 2  东西了!”孔乙己睁大眼睛说，“你怎么这样凭空污人清白……”“什么清白?我前天亲眼见你偷了何家...
# 3  渐复了原，旁人便又问道，“孔乙己，你当真认识字么?”孔乙己看着问他的人，显出不屑置辩的神气。...
# 4  �的答他道，“谁要你教，不是草头底下一个来回的回字么?”孔乙己显出极高兴的样子，将两个指头的...
# 5  …他打折了腿了。”掌柜说，“哦!”“他总仍旧是偷。这一回，是自己发昏，竟偷到丁举人家里去了。...
# 6  ��要好。”掌柜仍然同平常一样，笑着对他说，“孔乙己，你又偷了东西了!”但他这回却不十分分辩...
#
#                                       text_embedding  n_tokens  \
# 0  [-0.02892168238759041, 0.030343089252710342, -...       600
# 1  [-0.023281775414943695, 0.025943683460354805, ...       600
# 2  [-0.010134301148355007, 0.06756200641393661, -...       600
# 3  [-0.01448812149465084, 0.06170306354761124, -0...       600
# 4  [-0.003994992468506098, 0.07272820174694061, -...       600
# 5  [0.002749851206317544, 0.04300668090581894, -0...       600
# 6  [0.015753287822008133, 0.05899445340037346, -0...       408
#
#                          document_ids  \
# 0  [129084b0fa1815780605fa5c38c85b77]
# 1  [129084b0fa1815780605fa5c38c85b77]
# 2  [129084b0fa1815780605fa5c38c85b77]
# 3  [129084b0fa1815780605fa5c38c85b77]
# 4  [129084b0fa1815780605fa5c38c85b77]
# 5  [129084b0fa1815780605fa5c38c85b77]
# 6  [129084b0fa1815780605fa5c38c85b77]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [4119fd06010c494caa07f439b333f4c5, d3835bf3dda...
# 2  [4119fd06010c494caa07f439b333f4c5, d3835bf3dda...
# 3  [4119fd06010c494caa07f439b333f4c5, 19a7f254a5d...
# 4  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 5  [19a7f254a5d64566ab5cc15472df02de, e7ffaee9d31...
# 6  [19a7f254a5d64566ab5cc15472df02de, 9646481f66c...
#
#                                     relationship_ids
# 0  [e2bf260115514fb3b252fd879fb3e7be, 17ed1d92075...
# 1  [de6fa24480894518ab3cbcb66f739266, ef32c4b208d...
# 2  [de6fa24480894518ab3cbcb66f739266, ef32c4b208d...
# 3  [6fae5ee1a831468aa585a1ea09095998, b785a902506...
# 4  [b462b94ce47a4b8c8fffa33f7242acec, de6fa244808...
# 5  [b785a9025069417f94950ad231bb1441, 3b6cd96a273...
# 6  [b785a9025069417f94950ad231bb1441, 56d0e5ebe79...

# %%
# 记录每个原始文本包含的文本片段信息
df11 = pd.read_parquet(path_prefix + "create_base_documents.parquet")
df11
# Out:
#                                  id  \
# 0  129084b0fa1815780605fa5c38c85b77
#
#                                           text_units  \
# 0  [1fae6f3d55b5cb0dba1f89f668218cd2, 355e705881f...
#
#                                          raw_content         title
# 0  鲁镇的酒店的格局，是和别处不同的：都是当街一个尺形的大柜台，柜里面预备着热水，可以随时温酒。...  kongyiji.txt

# %%
# 汇总每个原始文本中提取的实体与关系信息
# 与create_base_documents相比，该工作流中包含对文本进行embedding的可选步骤
df12 = pd.read_parquet(path_prefix + "create_final_documents.parquet")
df12
# Out:
#                                  id  \
# 0  129084b0fa1815780605fa5c38c85b77
#
#                                        text_unit_ids  \
# 0  [1fae6f3d55b5cb0dba1f89f668218cd2, 355e705881f...
#
#                                          raw_content         title  \
# 0  鲁镇的酒店的格局，是和别处不同的：都是当街一个尺形的大柜台，柜里面预备着热水，可以随时温酒。...  kongyiji.txt
#
#                                raw_content_embedding
# 0  [0.01427625585347414, 0.047764863818883896, -0...
